# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#        id                        title  \
# 0  634649      Spider-Man: No Way Home
# 1   19404  Dilwale Dulhania Le Jayenge
# 2     278     The Shawshank Redemption
# 3     238                The Godfather
# 4  724089    Gabriel's Inferno Part II
#
#                                             overview release_date  popularity  \
# 0  Peter Parker is unmasked and no longer able to...   2021-12-15    7962.394
# 1  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      26.018
# 2  Framed in the 1940s for the double murder of h...   1994-09-23      66.144
# 3  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      56.724
# 4  Professor Gabriel Emerson finally learns the t...   2020-07-31      23.954
#
#    vote_average  vote_count
# 0           8.8         573
# 1           8.7        3276
# 2           8.7       20288
# 3           8.7       15178
# 4           8.7        1351

# %%
temp_df.tail()
# Out:
#         id                                              title  \
# 15     389                                       12 Angry Men
# 16     497                                     The Green Mile
# 17  644479                                 Dedicated to my ex
# 18  441130                                        Wolfwalkers
# 19  532067  KonoSuba: God's Blessing on this Wonderful Wor...
#
#                                              overview release_date  \
# 15  The defense and the prosecution have rested an...   1957-04-10
# 16  A supernatural tale set on death row in a Sout...   1999-12-10
# 17  The film tells the story of Ariel, a 21-year-o...   2019-11-01
# 18  In a time of superstition and magic, when wolv...   2020-10-26
# 19  It is not strange that the Demon Lord's forces...   2019-08-30
#
#     popularity  vote_average  vote_count
# 15      26.252           8.5        6017
# 16      49.298           8.5       13169
# 17      15.178           8.5         440
# 18      21.924           8.5         639
# 19     229.290           8.5         323

# %%
df = pd.DataFrame()

# %%
for i in range(1,20):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#          id                        title  \
# 0    634649      Spider-Man: No Way Home
# 1     19404  Dilwale Dulhania Le Jayenge
# 2       278     The Shawshank Redemption
# 3       238                The Godfather
# 4    724089    Gabriel's Inferno Part II
# ..      ...                          ...
# 675    3777              Throne of Blood
# 676  438631                         Dune
# 677   32085                      Vincent
# 678    5925             The Great Escape
# 679  152532           Dallas Buyers Club
#
#                                               overview release_date  \
# 0    Peter Parker is unmasked and no longer able to...   2021-12-15
# 1    Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 2    Framed in the 1940s for the double murder of h...   1994-09-23
# 3    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 4    Professor Gabriel Emerson finally learns the t...   2020-07-31
# ..                                                 ...          ...
# 675  Returning to their lord's castle, samurai warr...   1957-01-15
# 676  Paul Atreides, a brilliant and gifted young ma...   2021-09-15
# 677  Young Vincent Malloy dreams of being just like...   1982-10-01
# 678  The Nazis, exasperated at the number of escape...   1963-06-20
# 679  Loosely based on the true-life tale of Ron Woo...   2013-11-17
#
#      popularity  vote_average  vote_count
# 0      7962.394           8.8         573
# 1        26.018           8.7        3276
# 2        66.144           8.7       20288
# 3        56.724           8.7       15178
# 4        23.954           8.7        1351
# ..          ...           ...         ...
# 675      10.192           8.0         551
# 676     909.524           8.0        4765
# 677       9.058           8.0         659
# 678      13.163           8.0        1889
# 679      14.198           7.9        7047
#
# [680 rows x 7 columns]

# %%
df.shape
# Out:
# (680, 7)

# %%
df.to_csv('movies.csv')
